# %%
! pip install pandas seaborn statsmodels

# %% [markdown]
# ## Learning:

# %%
import pandas as pd
from utils.config import *
import importlib
import efc2_paper as paper
importlib.reload(paper)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

paper.learning_figure(measure='MD', fig_size=[6, 5], show_plot=True)
paper.learning_figure(measure='ET', fig_size=[6, 5], show_plot=True)
# Out:
# /Users/aghavamp/Desktop/Projects/ChordSynergy_JNP2025/efc2_paper.py:50: UserWarning:
# The palette list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=subset, x='adjusted_BN', y=measure+'_mean', hue='day',
# /Users/aghavamp/Desktop/Projects/ChordSynergy_JNP2025/efc2_paper.py:63: UserWarning:
# The palette list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=subset, x='adjusted_BN', y=measure+'_mean', hue='day',
# ========= MD STATS =========
# "untrained vs. trained:"
#     day1: t_13 = 0.4539, p = 6.5739154908885733e-01
#     day5: t_13 = -9.8770, p = 2.0765699707939643e-07
#     day5, last block: t_13 = -4.6435, p = 4.5986477484997399e-04
#     day5 untrained vs. day 2 trained: t_13 = -3.1958, p = 7.0246743679780671e-03
#
# "Block 1,2, day 5:"
#     untrained vs. trained: t_13 = -9.6962, p = 2.5704956639013856e-07
#
# rm-ANOVA trained:
# ...

# %% [markdown]
# ## Chord-specific improvement:

# %%
import pandas as pd
from utils.config import *
import importlib
import efc2_paper as paper
importlib.reload(paper)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

plt_type = 'box'
paper.imprv(measure='MD', fig_size=[2.5, 4], show_plot=True)
paper.imprv(measure='ET', fig_size=[2.5, 4], show_plot=True)
# Out:
# /Users/aghavamp/Desktop/Projects/ChordSynergy_JNP2025/efc2_paper.py:344: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend().set_visible(False)
# ========= MD STATS =========
# relative improvement: -18.352 +/- 19.642
#
# trained improvement vs. 0:
#     trained: t_13 = 12.601, p = 1.1603919336355822e-08
# untrained improvement vs. 0:
#    untrained: t_13 = -0.766, p = 4.5756167554306676e-01
#
# trained vs. untrained improvement:
#     t_13 = 5.483, p = 1.0510216164787816e-04
# /Users/aghavamp/Desktop/Projects/ChordSynergy_JNP2025/efc2_paper.py:344: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend().set_visible(False)
# ========= ET STATS =========
# relative improvement: -7.239 +/- 18.286
#
# ...

# %% [markdown]
# ## Average Trial Examples

# %%
import pandas as pd
from utils.config import *
import importlib
import efc2_paper as paper
importlib.reload(paper)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import utils.please
# %config InlineBackend.figure_format = 'retina'

# palette = ['#180a20','#471e61','#7632a2','#a15dcd','#c79ee1']
trial = None
sn = 111
chord = 21291
trial = [0, 80, 303]
# sn = 108
# chord = 19111
# trial = [0, 80, 307]
export_fig = False
df, mov = paper.plot_trial_example(sn=sn, chord=chord, trial=trial, fs=500, fig_size=[4, 3], t_minus=None, t_max=None, days=[1,4], num_trials=5, export_fig=export_fig)
# Out:
# subject 111, chord 21291, trained 1
#
# subject 111, chord 21291, trained 1
#
# trials: [0, 80, 303]
#
# ET: [9008. 6838. 1766.]
# MD: [1.75142137 1.9319887  1.25747988]

# %%
import pandas as pd
from utils.config import *
import importlib
import efc2_paper as paper
importlib.reload(paper)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import utils.please
# %config InlineBackend.figure_format = 'retina'

# palette = ['#180a20','#471e61','#7632a2','#a15dcd','#c79ee1']
trial = 'average'
sn = 102
chord = 22911
export_fig = False
days = [1,5]
# xlim = [3.6, 1.7, 0.9]
xlim = None
df, mov = paper.plot_trial_example(sn=sn, chord=chord, trial=trial, fs=500, fig_size=[4, 3], t_minus=None, t_max=None, 
                                   days=days, num_trials=5, xlim=xlim, export_fig=export_fig)
# Out:
# subject 102, chord 22911, trained 1
#
# average of day 1
# mean ET: 2366.255319148936
# mean MD: 1.3326979466543498
# average of day 5
# mean ET: 429.64444444444445
# mean MD: 0.2367626109075442

# %% [markdown]
# ## Finger Asynchrony

# %%
import pandas as pd
from utils.config import *
import importlib
import efc2_paper as paper
importlib.reload(paper)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'

paper.finger_asynch(fig_size=[6, 5])
# Out:
# /Users/aghavamp/Desktop/Projects/ChordSynergy_JNP2025/efc2_paper.py:659: UserWarning:
# The palette list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=subset, x='adjusted_BN', y='asynch_mean', hue='day',
# /Users/aghavamp/Desktop/Projects/ChordSynergy_JNP2025/efc2_paper.py:670: UserWarning:
# The palette list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=subset, x='adjusted_BN', y='asynch_mean', hue='day',
# day 1, run 1,2:
#     trained: 572.018ms +- 108.101
#     untrained: 439.598ms +- 83.0763
#
# day 5:
#     trained: 77.6429ms +- 20.7509
#     untrained: 121.125ms +- 32.372
